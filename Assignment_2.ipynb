# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in d:\software\anaconda\exe file\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in d:\software\anaconda\exe file\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\software\anaconda\exe file\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\software\anaconda\exe file\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\software\anaconda\exe file\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in d:\software\anaconda\exe file\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Read data from CSV file

# %%
df = pd.read_csv("taxi_trip_pricing.csv")
print(df.head())
# Out:
#    Trip_Distance_km Time_of_Day Day_of_Week  Passenger_Count  \
# 0             19.35     Morning     Weekday              3.0
# 1             47.59   Afternoon     Weekday              1.0
# 2             36.87     Evening     Weekend              1.0
# 3             30.33     Evening     Weekday              4.0
# 4               NaN     Evening     Weekday              3.0
#
#   Traffic_Conditions Weather  Base_Fare  Per_Km_Rate  Per_Minute_Rate  \
# 0                Low   Clear       3.56         0.80             0.32
# 1               High   Clear        NaN         0.62             0.43
# 2               High   Clear       2.70         1.21             0.15
# 3                Low     NaN       3.48         0.51             0.15
# 4               High   Clear       2.93         0.63             0.32
#
#    Trip_Duration_Minutes  Trip_Price
# 0                  53.82     36.2624
# 1                  40.57         NaN
# 2                  37.27     52.9032
# 3                 116.81     36.4698
# 4                  22.64     15.6180

# %% [markdown]
# Mean, Median, Variance, Standard Deviation for Columns having Continuous Numerical Values

# %%
df = df.dropna()
print("For Trip_Distance_km column")
print("Mean: ", df['Trip_Distance_km'].mean())
print("Median: ", df['Trip_Distance_km'].median())
print("Variance: ", df['Trip_Distance_km'].var())
print("Standard Deviation: ", df['Trip_Distance_km'].std())
print("\n")

print("For Passenger_Count column")
print("Mean: ", df['Passenger_Count'].mean())
print("Median: ", df['Per_Km_Rate'].median())
print("Variance: ", df['Per_Km_Rate'].var())
print("Standard Deviation: ", df['Per_Km_Rate'].std())
print("\n")

print("For Base_Fare column")
print("Mean: ", df['Base_Fare'].mean())
print("Median: ", df['Base_Fare'].median())
print("Variance: ", df['Base_Fare'].var())
print("Standard Deviation: ", df['Base_Fare'].std())
print("\n")

print("For Per_Km_Rate column")
print("Mean: ", df['Per_Km_Rate'].mean())
print("Median: ", df['Per_Km_Rate'].median())
print("Variance: ", df['Per_Km_Rate'].var())
print("Standard Deviation: ", df['Per_Km_Rate'].std())
print("\n")

print("For Per_Minute_Rate column")
print("Mean: ", df['Per_Minute_Rate'].mean())
print("Median: ", df['Per_Minute_Rate'].median())
print("Variance: ", df['Per_Minute_Rate'].var())
print("Standard Deviation: ", df['Per_Minute_Rate'].std())
print("\n")

print("For Trip_Duration_Minutes column")
print("Mean: ", df['Trip_Duration_Minutes'].mean())
print("Median: ", df['Trip_Duration_Minutes'].median())
print("Variance: ", df['Trip_Duration_Minutes'].var())
print("Standard Deviation: ", df['Trip_Duration_Minutes'].std())
print("\n")

print("For Trip_Price column")
print("Mean: ", df['Trip_Price'].mean())
print("Median: ", df['Trip_Price'].median())
print("Variance: ", df['Trip_Price'].var())
print("Standard Deviation: ", df['Trip_Price'].std())
print("\n")
# Out:
# For Trip_Distance_km column
# Mean:  27.77294090950703
# Median:  26.42
# Variance:  447.4568249408838
# Standard Deviation:  21.15317529216084
#
#
# For Passenger_Count column
# Mean:  2.5338078291814945
# Median:  1.2
# Variance:  0.1852021187381455
# Standard Deviation:  0.4303511574727614
#
#
# For Base_Fare column
# Mean:  3.5098932384341635
# Median:  3.545
# Variance:  0.7587839458009008
# Standard Deviation:  0.8710820545740228
#
#
# For Per_Km_Rate column
# Mean:  1.2198576512455515
# Median:  1.2
# Variance:  0.1852021187381455
# Standard Deviation:  0.4303511574727614
#
#
# For Per_Minute_Rate column
# Mean:  0.28822064056939506
# Median:  0.28
# Variance:  0.01318684606162105
# Standard Deviation:  0.11483399349330776
#
#
# For Trip_Duration_Minutes column
# Mean:  61.825088967971524
# Median:  61.209999999999994
# Variance:  1032.236406141803
# Standard Deviation:  32.12843609859968
#
#
# For Trip_Price column
# Mean:  57.66352488997793
# Median:  50.15785
# Variance:  1932.370936662731
# Standard Deviation:  43.958741299799875

# %% [markdown]
# Mode for Target Column

# %%
print("Mode:\n",df['Trip_Price'].mode())
# Out:
# Mode:
#  0        6.126900
# 1        6.472900
# 2        8.670900
# 3        8.729600
# 4        8.920300
#           ...
# 557    322.725996
# 558    325.098950
# 559    327.217665
# 560    328.871769
# 561    332.043689
# Name: Trip_Price, Length: 562, dtype: float64

# %% [markdown]
# Frequency and Percentage for Columns contains Categorical or Discrete Numerical Data

# %%
print("Analysis for 'Time_of_Day':")
frequency = df['Time_of_Day'].value_counts()
percentage = df['Time_of_Day'].value_counts(normalize=True) * 100
Time_of_day_analysis = pd.DataFrame({ "Frequency": frequency, "Percentage (%)": percentage})
print(Time_of_day_analysis)
print("\n")

print("Analysis for 'Day_of_Week':")
frequency = df['Day_of_Week'].value_counts()
percentage = df['Day_of_Week'].value_counts(normalize=True) * 100
Day_of_Week_analysis = pd.DataFrame({ "Frequency": frequency, "Percentage (%)": percentage})
print(Day_of_Week_analysis)
print("\n")

print("Analysis for 'Traffic_Conditions':")
frequency = df['Traffic_Conditions'].value_counts()
percentage = df['Traffic_Conditions'].value_counts(normalize=True) * 100
Traffic_Conditions_analysis = pd.DataFrame({ "Frequency": frequency, "Percentage (%)": percentage})
print(Traffic_Conditions_analysis)
print("\n")

print("Analysis for 'Weather':")
frequency = df['Weather'].value_counts()
percentage = df['Weather'].value_counts(normalize=True) * 100
Weather_analysis = pd.DataFrame({ "Frequency": frequency, "Percentage (%)": percentage})
print(Weather_analysis)
print("\n")
# Out:
# Analysis for 'Time_of_Day':
#              Frequency  Percentage (%)
# Time_of_Day
# Afternoon          220       39.145907
# Morning            157       27.935943
# Evening            124       22.064057
# Night               61       10.854093
#
#
# Analysis for 'Day_of_Week':
#              Frequency  Percentage (%)
# Day_of_Week
# Weekday            381       67.793594
# Weekend            181       32.206406
#
#
# Analysis for 'Traffic_Conditions':
#                     Frequency  Percentage (%)
# Traffic_Conditions
# Medium                    236       41.992883
# Low                       218       38.790036
# High                      108       19.217082
#
#
# Analysis for 'Weather':
#          Frequency  Percentage (%)
# Weather
# Clear          386       68.683274
# Rain           134       23.843416
# Snow            42        7.473310

# %% [markdown]
# Pie-Chart for Time_Of_Day Column

# %%
time_of_day_freq = df['Time_of_Day'].value_counts()
plt.figure(figsize=(8, 6))
time_of_day_freq.plot.pie(
    autopct='%1.1f%%',  
    startangle=90,      
    colors=['green', 'blue', 'red', 'violet'],  
    explode=[0.1 if i == time_of_day_freq.idxmax() else 0 for i in time_of_day_freq.index], 
    shadow=True   
)
plt.title("Distribution of 'Time_of_Day'")
plt.ylabel('')
plt.show()

# %% [markdown]
# Line Graph for Trip_Price

# %%
sorted_trip_price = df['Trip_Price'].dropna().sort_values().reset_index(drop=True)
plt.figure(figsize=(10, 6))
plt.plot(sorted_trip_price, color='blue', linewidth=2, label='Trip Price')
plt.title("Line Graph of Trip Prices", fontsize=16)
plt.xlabel("Index (Sorted by Price)", fontsize=12)
plt.ylabel("Trip Price", fontsize=12)
plt.grid(alpha=0.3)
plt.legend()
plt.show()

# %% [markdown]
# Correlation of Heatmap

# %%
import seaborn as sns

# %%
numeric_df = df.select_dtypes(include=['float', 'int'])

plt.figure(figsize=(8, 5))
correlation_matrix = numeric_df.corr() 
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# Bar-chart for Passenger Count

# %%
passenger_count_freq = df['Passenger_Count'].value_counts()
plt.figure(figsize=(8, 6))
passenger_count_freq.plot.bar(
    color=['green', 'blue', 'red', 'violet'],
    edgecolor='black',
    width=0.7
)
plt.title("Bar Chart of Passenger Count", fontsize=16)
plt.xlabel("Number of Passengers", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.xticks(rotation=0)
plt.grid(axis='y', alpha=0.3)
plt.show()

# %% [markdown]
# Converting categorical data to numerical data

# %%
df = pd.DataFrame({'Time_of_Day': ['Morning', 'Afternoon', 'Evening', 'Morning']})

frequency_encoded = df['Time_of_Day'].map(df['Time_of_Day'].value_counts())

df['Time_of_Day_Encoded'] = frequency_encoded

print(df)
# Out:
#   Time_of_Day  Time_of_Day_Encoded
# 0     Morning                    2
# 1   Afternoon                    1
# 2     Evening                    1
# 3     Morning                    2
